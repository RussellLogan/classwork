# %%
import pandas as pd

url = "https://raw.githubusercontent.com/nkmwicz/data-for-students/refs/heads/main/soccer-players.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32403 entries, 0 to 32402
# Data columns (total 23 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             32403 non-null  int64
#  1   first_name                            30345 non-null  str
#  2   last_name                             32403 non-null  str
#  3   name                                  32403 non-null  str
#  4   last_season                           32403 non-null  int64
#  5   current_club_id                       32403 non-null  int64
#  6   player_code                           32403 non-null  str
#  7   country_of_birth                      29600 non-null  str
#  8   city_of_birth                         29942 non-null  str
#  9   country_of_citizenship                32023 non-null  str
#  10  date_of_birth                         32356 non-null  str
# ...

# %%
df.describe()
# Out:
#           player_id   last_season  current_club_id  height_in_cm  \
# count  3.240300e+04  32403.000000     32403.000000  30059.000000
# mean   3.445789e+05   2019.337777      4809.252045    182.291161
# std    2.806831e+05      3.965914     11601.982978      6.971224
# min    1.000000e+01   2012.000000         3.000000     17.000000
# 25%    1.066980e+05   2016.000000       403.000000    178.000000
# 50%    2.824210e+05   2020.000000      1071.000000    183.000000
# 75%    5.242085e+05   2023.000000      3060.000000    187.000000
# max    1.309800e+06   2024.000000    110302.000000    207.000000
#
#        market_value_in_eur  highest_market_value_in_eur
# count         3.086900e+04                 3.086900e+04
# mean          1.611350e+06                 3.675045e+06
# std           6.362017e+06                 9.653897e+06
# min           1.000000e+04                 1.000000e+04
# 25%           1.000000e+05                 2.750000e+05
# ...

# %%
df["height_in_cm"].mean()
# Out:
# np.float64(182.29116071725608)

# %%
df["height_in_cm"].median()
# Out:
# np.float64(183.0)

# %%
df["height_in_cm"].mode()[0]
# Out:
# np.float64(180.0)

# %%
df["height_in_cm"].var()
# Out:
# np.float64(48.59796930609404)

# %%
df["height_in_cm"].std()
# Out:
# np.float64(6.9712243763986)

# %%
min_ht = df["height_in_cm"].min()
max_ht = df["height_in_cm"].max()
range_ht = max_ht - min_ht
print(f"range = {range_ht}, min={min_ht}, max={max_ht}")
# Out:
# range = 190.0, min=17.0, max=207.0

# %%
# %conda install scipy

# scipy stats PURE COMMENT

# from scipy import stats # error here, thats why I separated scipy from pandas

# scipy_skew = scipy.stats(df["height_in_cm"], nan_policy="omit")
# print(f"pd_skew={pd_skew}; scipy_skew = {scipy_skew}")

# scipy_kurt = stats.kurtosis(df["height_in_cm"].dropna())
# scipy_kurt_omit = stats.kurtosis(df["height_in_cm"], nan_policy="omit")

# print(f"pd_kurt = {pd_kurt}\nscipy_kurt={scipy_kurt}/nscipy_kurt_omit={scipy_kurt_omit}")

# %%
pd_skew = df["height_in_cm"].skew()
pd_skew
# Out:
# np.float64(-1.7751475048518246)

# %%
pd_kurt = df["height_in_cm"].kurt()
pd_kurt
# Out:
# np.float64(40.3723954752419)

# %% [markdown]
# - MAKING A FUNCTION (has not yet been run due to pandas)

# %%
import pandas as pd
import numpy as np
def eda(df: pd.DataFrame) -> pd.DataFrame:
    """
    Do stat eval on dataframe
    
    Args"
        df(pd.DataFrame): Dataframe to evaluatate
    Returns:
        pd.DataFrame: New DataFrame with column eval
    """
    
    data = []
    index = df.columns
    new_columns = [
        "is_numeric",
        "min",
        "max",
        "range",
        "std",
        "num_na",
        "perc_na",
        "num_unique",
        "unique_vals"]
    total_vals = len(df)
    for col in df.columns:
        num_na = df[col].isna().sum()
        perc_na = round(num_na / total_vals, 4)
        num_unique = df[col].nunique()
        if pd.api.types.is_numeric_dtype(df[col]):
            is_num = True
            max = df[col].max()
            min = df[col].min()
            rng = max - min
            std = round(df[col].std(),4)
            unique_vals = np.nan
            row = [is_num, min, max, rng, std, num_na, perc_na, num_unique, unique_vals]
            data.append(row)
        else:
            is_num = False
            max = np.nan
            min = np.nan
            rng = np.nan
            std = np.nan
            unique_vals = df[col].unique() if num_unique < 8 else np.nan
            row = [is_num, min, max, rng, std, num_na, perc_na, num_unique, unique_vals]
            data.append(row)
    new_df = pd.DataFrame(data=data,columns=new_columns,index=index)
    return new_df

# %%
cats_df = eda(df)
cats_df.loc["height_in_cm"]
# Out:
# is_numeric       True
# min              17.0
# max             207.0
# range           190.0
# std            6.9712
# num_na           2344
# perc_na        0.0723
# num_unique         52
# unique_vals       NaN
# Name: height_in_cm, dtype: object
