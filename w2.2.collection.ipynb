# %% [markdown]
# **Collections**
#
# -set
#
# -tuple
#
# -list
#
# -dict (dictionary)

# %%
# set
# mutable, unordered (no index), no duplicates, iterable

set_inferred = {1,2,3,2} # almost never do this
set_explicit = set((2,3,4,4))

print(f"set_inferred = {set_inferred}")
print(f"set_explicit = {set_explicit}")
# Out:
# set_inferred = {1, 2, 3}
# set_explicit = {2, 3, 4}

# %%
set_inferred.add(7)                               # add
print(f"add = {set_inferred}")
set_inferred.remove(3)                            # remove
print(f"removed set_inferred = {set_inferred}")
diff = set_inferred.difference(set_explicit)      # get the difference between sets
print(f"diff = {diff}")
overlap = set_inferred.intersection(set_explicit) # get overlaps between sets
print(f"overlap = {overlap}")
# Out:
# add = {1, 2, 3, 7}
# removed set_inferred = {1, 2, 7}
# diff = {1, 7}
# overlap = {2}

# %%
# tuple
# immutable, ordered (index), duplicates, iterable
tuple_inferred = (1,2,3,3,5,6)
tuple_explicit = tuple([4,5,6,7,2])

print(f"tuple_inferred = {tuple_inferred}")
print(f"tuple_explicit = {tuple_explicit}")
# Out:
# tuple_inferred = (1, 2, 3, 3, 5, 6)
# tuple_explicit = (4, 5, 6, 7, 2)

# %%
# index notation
# [start:stop:step]
print(f"index 0 = {tuple_inferred[0]}")
print(f"last item = {tuple_inferred[-1]}")
print(f"get 2nd and 3rd items = {tuple_inferred[1:3]}")
print(f"all but the last three = {tuple_inferred[:-3]}")
print(f"we only want the last three = {tuple_inferred[-3:]}")
print(f"tuple_inferred has {len(tuple_inferred)} elements")
# Out:
# index 0 = 1
# last item = 6
# get 2nd and 3rd items = (2, 3)
# all but the last three = (1, 2, 3)
# we only want the last three = (3, 5, 6)
# tuple_inferred has 6 elements

# %%
# tuple methods
count = tuple_inferred.count(3) # get number of value
idx = tuple_inferred.index(3)   # get index of value

print(count)
print(idx)
# Out:
# 2
# 2

# %%
# list
# mutable, ordered (index), duplicates, iterable
list_inferred = [1,2,3,4,5,5,6,3]
list_explicit = list((4,5,6,1,1,3,2))

print(f"list_inferred = {list_inferred}")
print(f"list_explicit = {list_explicit}")
# Out:
# list_inferred = [1, 2, 3, 4, 5, 5, 6, 3]
# list_explicit = [4, 5, 6, 1, 1, 3, 2]

# %%
# list methods

newlist = list_inferred.append(7)         # add
print(f"append = {list_inferred}")
print(f"new list = {newlist}")

list_inferred.remove(5)                   # remove
print(f"remove = {list_inferred}")

removed = list_inferred.pop()             # pop removes last item or at index
print(f"removed = {removed}")
print(f"after pop = {list_inferred}")
# Out:
# append = [1, 2, 3, 4, 5, 5, 6, 3, 7]
# new list = None
# remove = [1, 2, 3, 4, 5, 6, 3, 7]
# removed = 7
# after pop = [1, 2, 3, 4, 5, 6, 3]

# %%
# changing
list_inferred[0] = "Awsome Index"
list_inferred
# Out:
# ['Awsome Index', 2, 3, 4, 5, 6, 3]

# %%
# dict (dictionary)
# mutable, {key:value}, unordered (index by key)
# no duplicate keys, but duplicate values, iterable
dict_inferred = {
    "name": "John",
    "age": 30,
}
dict_explicit = dict(city="new york", country="usa")

print(f"dict_inferred = {dict_inferred}")
print(f"dict_explicit = {dict_explicit}")
# Out:
# dict_inferred = {'name': 'John', 'age': 30}
# dict_explicit = {'city': 'new york', 'country': 'usa'}

# %%
dict_inferred["age"]
# Out:
# 30

# %%
dict_inferred["gender"] = "m"
dict_inferred
# Out:
# {'name': 'John', 'age': 30, 'gender': 'm'}

# %%
dict_inferred["eye_color"] = "blue"
dict_inferred
# Out:
# {'name': 'John', 'age': 30, 'gender': 'm', 'eye_color': 'blue'}

# %%
dict_inferred["age"] = 72
dict_inferred
# Out:
# {'name': 'John', 'age': 72, 'gender': 'm', 'eye_color': 'blue'}
